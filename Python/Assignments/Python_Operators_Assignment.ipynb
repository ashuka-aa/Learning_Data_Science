# %% [markdown]
# #### Qn:1
# (7 ^ 3) * (8 >> 2) + 9 % 4
# = 4 * (8 >> 2) + 9 % 4
# = 4 * 2 + 9 % 4
# = 8 + 9 % 4
# = 8 + 1
# = 9

# %%
exp = (7 ^ 3) * (8 >> 2) + 9 % 4

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 9

# %% [markdown]
# #### Qn:2
# (14 >> 1) + (9 % 5) * (6 ^ 2)
# = 7 + (9 % 5) * (6 ^ 2)
# = 7 + 4 * (6 ^ 2)
# = 7 + 4 * 4
# = 7 + 16
# = 23

# %%
exp = (14 >> 1) + (9 % 5) * (6 ^ 2)

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 23

# %% [markdown]
# #### Qn:3
# (5**3 // 4 % 7 << 2) + (18 >> 2) * (9 ^ 6 % 5)
# = (125 // 4 % 7 << 2) + (18 >> 2) * (9 ^ 6 % 5)
# = (31 % 7 << 2) + (18 >> 2) * (9 ^ 6 % 5)
# = (3 << 2) + (18 >> 2) * (9 ^ 6 % 5)
# = 12 + (18 >> 2) * (9 ^ 6 % 5)
# = 12 + 4 * (9 ^ 6 % 5)
# = 12 + 4 * (9 ^ 1)
# = 12 + 4 * 8
# = 12 + 32
# = 44

# %%
exp = (5**3 // 4 % 7 << 2) + (18 >> 2) * (9 ^ 6 % 5)

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 44

# %% [markdown]
# #### Qn:4
# (27 % 5 * 3**2 // 4) ^ (48 >> 3) + (14 & 9 << 1)
# = (27 % 5 * 9 // 4) ^ (48 >> 3) + (14 & 9 << 1)
# = (2 * 9 // 4) ^ (48 >> 3) + (14 & 9 << 1)
# = (18 // 4) ^ (48 >> 3) + (14 & 9 << 1)
# = 4 ^ (48 >> 3) + (14 & 9 << 1)
# = 4 ^ 6 + (14 & 9 << 1)
# = 4 ^ 6 + (14 & 18)
# = 4 ^ 6 + 2
# = 4 ^ 8
# = 12

# %%
exp = (27 % 5 * 3**2 // 4) ^ (48 >> 3) + (14 & 9 << 1)

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 12

# %% [markdown]
# #### Qn:5
# ((19 | 6) ^ (28 & 14)) * (3 << 2) % (5 ** 2 // 3)
# = (23 ^ (28 & 14)) * (3 << 2) % (5 ** 2 // 3)
# = (23 ^ 12) * (3 << 2) % (5 ** 2 // 3)
# = 27 * (3 << 2) % (5 ** 2 // 3)
# = 27 * 12 % (5 ** 2 // 3)
# = 27 * 12 % (25 // 3)
# = 27 * 12 % 8
# = 324 % 8
# = 4

# %%
exp = ((19 | 6) ^ (28 & 14)) * (3 << 2) % (5 ** 2 // 3)

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 4

# %% [markdown]
# #### Qn:6
# (45 & 27) << 2 // (9 % 4 + 2 ** 3) + (16 ^ (5 << 1))
# = 9 << 2 // (9 % 4 + 2 ** 3) + (16 ^ (5 << 1))
# = 9 << 2 // (9 % 4 + 8) + (16 ^ (5 << 1))
# = 9 << 2 // (1 + 8) + (16 ^ (5 << 1))
# = 9 << 2 // 9 + (16 ^ (5 << 1))
# = 9 << 2 // 9 + (16 ^ 10)
# = 9 << 2 // 9 + 26
# = 9 << 0 + 26
# = 9 << 26
# = 603979776

# %%
exp = (45 & 27) << 2 // (9 % 4 + 2 ** 3) + (16 ^ (5 << 1)) 

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 603979776

# %% [markdown]
# #### Qn:7
# ((15 ** 2 % 7 + 48 >> 2) ^ (19 & 13 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 ** 2 + 5)) or (27 // 4 % 3 == 2)
# = ((225 % 7 + 48 >> 2) ^ (19 & 13 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 ** 2 + 5)) or (27 // 4 % 3 == 2)
# = ((1 + 48 >> 2) ^ (19 & 13 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3**3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = ((49 >> 2) ^ (19 & 13 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3 **3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 ** 2 + 5)) or (27 // 4 % 3 == 2)
# = (12 ^ (19 & 13 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = (12 ^ (1 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = (12 ^ 7) * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * (7 << 0) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * 7 + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * 7 + ((42 % 5 * 27 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * 7 + ((2 * 27 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * 7 + ((54 // 4) > (18 >> 1))
# and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5)) or (27 // 4 % 3 == 2)
# = 11 * 7 + (13 > (18 >> 1)) and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5))
# or (27 // 4 % 3 == 2)
# = 11 * 7 + (13 > 9) and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5))
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not ((9 | 4) ^ (12 & 7) < (3 **2 + 5))
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not (15 ^ (12 & 7) < (3 **2 + 5))
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not (15 ^ 4 < (3 **2 + 5))
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not (15 ^ 4 < (9 + 5))
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not (15 ^ 4 < 14)
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not (11 < 14)
# or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and not (1) or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and 0 or (27 // 4 % 3 == 2)
# = 11 * 7 + 1 and 0 or (6 % 3 == 2)
# = 11 * 7 + 1 and 0 or (0 == 2)
# = 11 * 7 + 1 and 0 or 0
# = 77 + 1 and 0 or 0
# = 78 and 0 or 0
# = 0 or 0
# = 0 (False)

# %%
exp = (((15 ** 2 % 7 + 48 >> 2) ^ (19 & 13 | 6)) * (7 << 3 // 5) + ((42 % 5 * 3 ** 3 // 4) > (18 >> 1))
and not ((9 | 4) ^ (12 & 7) < (3 ** 2 + 5)) or (27 // 4 % 3 == 2))

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is False

# %% [markdown]
# #### Qn:8
# ((63 & 45) << 1 | (72 >> 3)) ^ ((11 % 3 * 2**4) // (6 + 1))
# \+ (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = (45 << 1 | (72 >> 3)) ^ ((11 % 3 * 2 ** 4) // (6 + 1))
# \+ (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = (45 << 1 | 9) ^ ((11 % 3 * 2 ** 4) // (6 + 1))
# \+ (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = (90 | 9) ^ ((11 % 3 * 2 ** 4) // (6 + 1))
# \+ (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ ((11 % 3 * 2 **4) // (6 + 1))
# \+ (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ ((11 % 3 * 16) // (6 + 1)) + (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ ((2 * 16) // (6 + 1)) + (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ (32 // (6 + 1)) + (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ (32 // 7) + (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ 4 + (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ 4 + ((11 ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ 4 + (14 * (16 >> 2) % 7)- ((25 % 6) << 2)
# = 91 ^ 4 + (14 * 4 % 7)- ((25 % 6) << 2)
# = 91 ^ 4 + (56 % 7) - ((25 % 6) << 2)
# = 91 ^ 4 + 0 - ((25 % 6) << 2)
# = 91 ^ 4 - (1 << 2)
# = 91 ^ 0
# = 91

# %%
exp = (((63 & 45) << 1 | (72 >> 3)) ^ ((11 % 3 * 2**4) // (6 + 1))
+ (((8 | 3) ^ 5) * (16 >> 2) % 7)- ((25 % 6) << 2))

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 91

# %% [markdown]
# #### Qn:9
# (((128 >> 3) & (45 | 18)) ^ (7** 2 % 10)) * ((36 // 5) << 1)
# \- ((91 % 7 * 2 ** 3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = ((16 & (45 | 18)) ^ (7** 2 % 10)) * ((36 // 5) << 1)
# \- ((91 % 7 * 2 ** 3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = ((16 & 63) ^ (7** 2 % 10)) * ((36 // 5) << 1)
# \- ((91 % 7 * 2 ** 3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = (16 ^ (7** 2 % 10)) * ((36 // 5) << 1)
# \- ((91 % 7 * 2 ** 3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = (16 ^ (49 % 10)) * ((36 // 5) << 1)
# \- ((91 % 7 * 2 **3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = (16 ^ 9) * ((36 // 5) << 1)
# \- ((91 % 7 * 2 **3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * ((36 // 5) << 1) - ((91 % 7 * 2 **3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * (7 << 1) - ((91 % 7 * 2 **3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * 14 - ((91 % 7 * 2 **3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * 14 - ((91 % 7 * 8) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * 14 - ((0 * 8) ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * 14 - (0 ^ (54 & 23)) + ((15 | 6) >> 1) % 5
# = 25 * 14 - (0 ^ 22) + ((15 | 6) >> 1) % 5
# = 25 * 14 - 22 + ((15 | 6) >> 1) % 5
# = 25 * 14 - 22 + (15 >> 1) % 5
# = 25 * 14 - 22 + 7 % 5
# = 350 - 22 + 7 % 5
# = 350 - 22 + 2
# = 328 + 2
# = 330

# %%
exp = ((((128 >> 3) & (45 | 18)) ^ (7**2 % 10)) * ((36 // 5) << 1)
- ((91 % 7 * 2**3) ^ (54 & 23)) + ((15 | 6) >> 1) % 5)

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is 330

# %% [markdown]
# #### Qn:10
# (((17**2 % 13) << 2) ^ ((64 >> 2) | (9 & 5))) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = (((289 % 13) << 2) ^ ((64 >> 2) | (9 & 5))) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = ((3 << 2) ^ ((64 >> 2) | (9 & 5))) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = (12 ^ ((64 >> 2) | (9 & 5))) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = (12 ^ (16 | (9 & 5))) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = (12 ^ (16 | 1)) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = (12 ^ 17) > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > ((45 % 7 * 3 ** 2) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > ((45 % 7 * 9) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > ((3 * 9) // 6)
# and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > (27 // 6) and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not ((28 ^ (35 & 19)) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not ((28 ^ 3) < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not (31 < (2 ** 5 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not (31 < (32 + 7 % 3))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not (31 < (32 + 1))
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not (31 < 33)
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not (1)
# or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (((9 << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or ((18 % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (3 == 3 and ((56 >> 3) & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (3 == 3 and (7 & (15 | 4)) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (3 == 3 and (7 & 15) != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (3 == 3 and 7 != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (1 and 7 != 7)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or (1 and 0)
# and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or 0 and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or 0 and not ((99 % 8 * 8 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or 0 and not ((3 * 8 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or 0 and not ((24 // 5) ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or 0 and not (4 ^ (42 & 27) > 25)
# = 29 > 4 and not 1 or 0 and not (4 ^ 10 > 25)
# = 29 > 4 and not 1 or 0 and not (14 > 25)
# = 29 > 4 and not 1 or 0 and not 0
# = 1 and not 1 or 0 and not 0
# = 1 and 0 or 0 and not 0
# = 1 and 0 or 0 and 1
# = 0 or 0 and 1
# = 0 or 0
# = 0 (False)

# %%
exp = ((((17**2 % 13) << 2) ^ ((64 >> 2) | (9 & 5))) > ((45 % 7 * 3 ** 2) // 6)  
and not (((28 | 12) ^ (35 & 19)) < (2 ** 5 + 7 % 3))  
or ((((81 // 9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7)  
and not ((99 % 8 * 2 ** 3 // 5) ^ (42 & 27) > 25))

print(f'The value of the given expression is {exp}')
# Out:
# The value of the given expression is False
